# %% [markdown]
# Case studies:

# %%
import pandas as pd

geipan_cases = pd.read_csv('/Users/javarome/PycharmProjects/ufoml/data/geipan/Export_etudedecas.csv', sep = '|', encoding='iso-8859-1')
geipan_cases.head()
# Out:
#         NumEtude                           NomEtude   Latitude Longitude  \
# 0  1952-09-08193  CRECY-EN-PONTHIEU (80) 21.09.1952      50,25  1,883333
# 1  1960-04-02014         PIERREFORT (15) --.--.1960  44,916667  2,833333
# 2  1960-07-08172            WISSOUS (91) 01.07.1960  48,733333  2,333333
# 3  1963-11-01791         PREMESQUES (59) 11.11.1963      50,65      2,95
# 4  1964-03-01780  LE BOURGET DU LAC (73) 01.03.1964        NaN       NaN
#
#   DateObservationEtude DepartementEtude NomduDepartement         RegionEtude  \
# 0           21/09/1952               80            Somme            Picardie
# 1           01/04/1960               15           Cantal            Auvergne
# 2           01/07/1960               91          Essonne       Ile-de-France
# 3           11/11/1963               59             Nord  Nord-Pas-de-Calais
# 4           01/03/1964               73           Savoie         Rhône Alpes
#
# ...

# %% [markdown]
# PV:

# %%
geipan_pv = pd.read_csv('/Users/javarome/PycharmProjects/ufoml/data/geipan/Export_PVTemoignage.csv', sep = '|', encoding='iso-8859-1')
geipan_pv.head()
# Out:
#         NumEtude    NumSEPRA  NumPV  NumTemoignage TypeTemoignage  \
# 0  1952-09-08193  1952110624    NaN              1      Terrestre
# 1  1960-04-02014  1960110164    NaN              1      Terrestre
# 2  1960-04-02014  1960110164    NaN              2      Terrestre
# 3  1960-07-08172  1960110531    NaN              1      Terrestre
# 4  1963-11-01791  1963110542    NaN              1      Terrestre
#
#   DateObservation NumPiece CR_Reference DateCR                        idAge  \
# 0      21/09/1952      NaN          NaN    NaN   Adulte (au-delà de 60 ans)
# 1      01/04/1960      NaN          NaN    NaN                  Non précisé
# 2      01/04/1960      NaN          NaN    NaN   Adulte (au-delà de 60 ans)
# 3      01/07/1960      NaN          NaN    NaN  Adolescent (de 13 à 18 ans)
# 4      11/11/1963      NaN          NaN    NaN   Adulte (au-delà de 18 ans)
#
#                          ...                         idEffetEnvironnemen1  \
# ...

# %% [markdown]
# We merge:

# %%
data = geipan_cases.merge(geipan_pv, on='NumEtude')
data.head()
# Out:
#         NumEtude                           NomEtude   Latitude Longitude  \
# 0  1952-09-08193  CRECY-EN-PONTHIEU (80) 21.09.1952      50,25  1,883333
# 1  1960-04-02014         PIERREFORT (15) --.--.1960  44,916667  2,833333
# 2  1960-04-02014         PIERREFORT (15) --.--.1960  44,916667  2,833333
# 3  1960-07-08172            WISSOUS (91) 01.07.1960  48,733333  2,333333
# 4  1963-11-01791         PREMESQUES (59) 11.11.1963      50,65      2,95
#
#   DateObservationEtude DepartementEtude NomduDepartement         RegionEtude  \
# 0           21/09/1952               80            Somme            Picardie
# 1           01/04/1960               15           Cantal            Auvergne
# 2           01/04/1960               15           Cantal            Auvergne
# 3           01/07/1960               91          Essonne       Ile-de-France
# 4           11/11/1963               59             Nord  Nord-Pas-de-Calais
#
# ...
